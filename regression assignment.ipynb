# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#housing = r'C:\Users\user\Desktop\DESKTOP\ADS ASSIGMENTS\regressins\BostonHousing.csv'
housing= r'C:\Users\user\Desktop\DESKTOP\ADS ASSIGMENTS\regressions\BostonHousing.csv'
boston_df = pd.read_csv(housing)
boston_df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296  \
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(boston_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
# Distribution of target variable
plt.figure(figsize=(8, 6))
sns.histplot(boston_df, kde=True)
plt.title('Distribution of Target Variable')
# Out:
# Text(0.5, 1.0, 'Distribution of Target Variable')

# %%
# Preprocessing
# Check for missing values
print(boston_df.isnull().sum())
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
boston_df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296  \
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
print(boston_df.head())
print(boston.keys())
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3  \
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
print(boston_df.keys())
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
boston_df.tail(10)
#boston_df.plot("median_income", "median_house_value")
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio
# 496  0.28960  0.0   9.69     0  0.585  5.390  72.9  2.7986    6  391     19.2  \
# 497  0.26838  0.0   9.69     0  0.585  5.794  70.6  2.8927    6  391     19.2
# 498  0.23912  0.0   9.69     0  0.585  6.019  65.3  2.4091    6  391     19.2
# 499  0.17783  0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391     19.2
# 500  0.22438  0.0   9.69     0  0.585  6.027  79.7  2.4982    6  391     19.2
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 496  396.90  21.14  19.7
# 497  396.90  14.10  18.3
# 498  396.90  12.92  21.2
# ...

# %%
import pandas as pd
import numpy as np


data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %%
data_url="https://github.com/selva86/datasets/blob/master/BostonHousing.csv"
boston=pd.read_csv(data_url,error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 2
#       1 data_url="https://github.com/selva86/datasets/blob/master/BostonHousing.csv"
# ----> 2 boston=pd.read_csv(data_url,error_bad_lines=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'
